# %%
import shutil
import os
import numpy as np
import random
import argparse

# %%
from shutil import copyfile

# %%
def img_train_test_split(img_source_dir, train_size):
    """
    Randomly splits images over a train and validation folder, while preserving the folder structure
    
    Parameters
    ----------
    img_source_dir : string
        Path to the folder with the images to be split. Can be absolute or relative path   
        
    train_size : float
        Proportion of the original images that need to be copied in the subdirectory in the train folder
    """    
    if not (isinstance(img_source_dir, str)):
        raise AttributeError('img_source_dir must be a string')
        
    if not os.path.exists(img_source_dir):
        raise OSError('img_source_dir does not exist')
        
    if not (isinstance(train_size, float)):
        raise AttributeError('train_size must be a float')
        
    # Set up empty folder structure if not exists
    if not os.path.exists('data'):
        os.makedirs('data')
    else:
        if not os.path.exists('data/train'):
            os.makedirs('data/train')
        if not os.path.exists('data/validation'):
            os.makedirs('data/validation')
            
    # Get the subdirectories in the main image folder
    subdirs = [subdir for subdir in os.listdir(img_source_dir) if os.path.isdir(os.path.join(img_source_dir, subdir))]

    for subdir in subdirs:
        subdir_fullpath = os.path.join(img_source_dir, subdir)
        if len(os.listdir(subdir_fullpath)) == 0:
            print(subdir_fullpath + ' is empty')
            break

        train_subdir = os.path.join('data/train', subdir)
        validation_subdir = os.path.join('data/validation', subdir)

        # Create subdirectories in train and validation folders
        if not os.path.exists(train_subdir):
            os.makedirs(train_subdir)

        if not os.path.exists(validation_subdir):
            os.makedirs(validation_subdir)

        train_counter = 0
        validation_counter = 0

        # Randomly assign an image to train or validation folder
        for filename in os.listdir(subdir_fullpath):
            if filename.endswith(".jpg") or filename.endswith(".png"): 
                fileparts = filename.split('.')

                if random.uniform(0, 1) <= train_size:
                    copyfile(os.path.join(subdir_fullpath, filename), os.path.join(train_subdir, str(train_counter) + '.' + fileparts[1]))
                    train_counter += 1
                else:
                    copyfile(os.path.join(subdir_fullpath, filename), os.path.join(validation_subdir, str(validation_counter) + '.' + fileparts[1]))
                    validation_counter += 1
                    
        print('Copied ' + str(train_counter) + ' images to data/train/' + subdir)
        print('Copied ' + str(validation_counter) + ' images to data/validation/' + subdir)

# %%
img_train_test_split('/content/drive/My Drive/face_age',0.5)
# Out:
# Copied 84 images to data/train/005
# Copied 96 images to data/validation/005
# Copied 592 images to data/train/001
# Copied 540 images to data/validation/001
# Copied 81 images to data/train/009
# Copied 78 images to data/validation/009
# Copied 142 images to data/train/003
# Copied 142 images to data/validation/003
# Copied 118 images to data/train/008
# Copied 118 images to data/validation/008
# Copied 77 images to data/train/010
# Copied 63 images to data/validation/010
# Copied 232 images to data/train/002
# Copied 243 images to data/validation/002
# Copied 124 images to data/train/004
# Copied 136 images to data/validation/004
# Copied 54 images to data/train/006
# Copied 60 images to data/validation/006
# Copied 60 images to data/train/007
# Copied 66 images to data/validation/007
# Copied 106 images to data/train/016
# Copied 106 images to data/validation/016
# Copied 68 images to data/train/014
# Copied 69 images to data/validation/014
# Copied 70 images to data/train/015
# Copied 73 images to data/validation/015
# Copied 52 images to data/train/017
# Copied 51 images to data/validation/017
# Copied 86 images to data/train/018
# Copied 95 images to data/validation/018
# Copied 26 images to data/train/019
# Copied 32 images to data/validation/019
# Copied 37 images to data/train/013
# Copied 38 images to data/validation/013
# Copied 29 images to data/train/011
# Copied 34 images to data/validation/011
# Copied 50 images to data/train/020
# Copied 53 images to data/validation/020
# Copied 48 images to data/train/012
# Copied 58 images to data/validation/012
# Copied 82 images to data/train/025
# Copied 74 images to data/validation/025
# Copied 97 images to data/train/024
# Copied 94 images to data/validation/024
# Copied 55 images to data/train/030
# Copied 54 images to data/validation/030
# Copied 43 images to data/train/023
# Copied 49 images to data/validation/023
# Copied 69 images to data/train/028
# Copied 76 images to data/validation/028
# Copied 123 images to data/train/026
# Copied 156 images to data/validation/026
# Copied 71 images to data/train/022
# Copied 68 images to data/validation/022
# Copied 78 images to data/train/029
# Copied 72 images to data/validation/029
# Copied 56 images to data/train/027
# Copied 70 images to data/validation/027
# Copied 64 images to data/train/021
# Copied 72 images to data/validation/021
# Copied 46 images to data/train/034
# Copied 41 images to data/validation/034
# Copied 48 images to data/train/038
# Copied 43 images to data/validation/038
# Copied 44 images to data/train/040
# Copied 41 images to data/validation/040
# Copied 67 images to data/train/035
# Copied 54 images to data/validation/035
# Copied 71 images to data/train/032
# Copied 70 images to data/validation/032
# Copied 51 images to data/train/031
# Copied 46 images to data/validation/031
# Copied 76 images to data/train/039
# Copied 60 images to data/validation/039
# Copied 46 images to data/train/037
# Copied 48 images to data/validation/037
# Copied 28 images to data/train/033
# Copied 18 images to data/validation/033
# Copied 54 images to data/train/036
# Copied 58 images to data/validation/036
# Copied 26 images to data/train/041
# Copied 30 images to data/validation/041
# Copied 44 images to data/train/045
# Copied 33 images to data/validation/045
# Copied 49 images to data/train/049
# Copied 50 images to data/validation/049
# Copied 50 images to data/train/050
# Copied 55 images to data/validation/050
# Copied 53 images to data/train/042
# Copied 31 images to data/validation/042
# Copied 16 images to data/train/044
# Copied 11 images to data/validation/044
# Copied 38 images to data/train/047
# Copied 32 images to data/validation/047
# Copied 27 images to data/train/046
# Copied 34 images to data/validation/046
# Copied 32 images to data/train/048
# Copied 32 images to data/validation/048
# Copied 23 images to data/train/043
# Copied 29 images to data/validation/043
# Copied 66 images to data/train/056
# Copied 66 images to data/validation/056
# Copied 24 images to data/train/057
# Copied 36 images to data/validation/057
# Copied 28 images to data/train/051
# Copied 34 images to data/validation/051
# Copied 55 images to data/train/054
# Copied 51 images to data/validation/054
# Copied 31 images to data/train/059
# Copied 28 images to data/validation/059
# Copied 25 images to data/train/055
# Copied 27 images to data/validation/055
# Copied 69 images to data/train/060
# Copied 68 images to data/validation/060
# Copied 52 images to data/train/058
# Copied 44 images to data/validation/058
# Copied 59 images to data/train/052
# Copied 74 images to data/validation/052
# Copied 66 images to data/train/053
# Copied 67 images to data/validation/053
# Copied 30 images to data/train/066
# Copied 24 images to data/validation/066
# Copied 55 images to data/train/065
# Copied 58 images to data/validation/065
# Copied 28 images to data/train/063
# Copied 19 images to data/validation/063
# Copied 16 images to data/train/064
# Copied 13 images to data/validation/064
# Copied 16 images to data/train/069
# Copied 29 images to data/validation/069
# Copied 25 images to data/train/070
# Copied 28 images to data/validation/070
# Copied 33 images to data/train/062
# Copied 43 images to data/validation/062
# Copied 23 images to data/train/068
# Copied 35 images to data/validation/068
# Copied 31 images to data/train/067
# Copied 16 images to data/validation/067
# Copied 23 images to data/train/061
# Copied 27 images to data/validation/061
# Copied 13 images to data/train/071
# Copied 9 images to data/validation/071
# Copied 36 images to data/train/075
# Copied 51 images to data/validation/075
# Copied 7 images to data/train/074
# Copied 9 images to data/validation/074
# Copied 38 images to data/train/080
# Copied 33 images to data/validation/080
# Copied 33 images to data/train/072
# Copied 37 images to data/validation/072
# Copied 7 images to data/train/079
# Copied 9 images to data/validation/079
# Copied 16 images to data/train/076
# Copied 19 images to data/validation/076
# Copied 15 images to data/train/078
# Copied 15 images to data/validation/078
# Copied 9 images to data/train/077
# Copied 10 images to data/validation/077
# Copied 23 images to data/train/073
# Copied 8 images to data/validation/073
# Copied 16 images to data/train/082
# Copied 13 images to data/validation/082
# Copied 4 images to data/train/083
# Copied 3 images to data/validation/083
# Copied 8 images to data/train/089
# Copied 8 images to data/validation/089
# Copied 3 images to data/train/087
# Copied 1 images to data/validation/087
# Copied 11 images to data/train/088
# Copied 6 images to data/validation/088
# Copied 10 images to data/train/086
# Copied 12 images to data/validation/086
# Copied 8 images to data/train/081
# Copied 2 images to data/validation/081
# Copied 68 images to data/train/085
# Copied 62 images to data/validation/085
# Copied 6 images to data/train/084
# Copied 5 images to data/validation/084
# Copied 28 images to data/train/090
# Copied 27 images to data/validation/090
# Copied 0 images to data/train/093
# Copied 3 images to data/validation/093
# Copied 1 images to data/train/091
# Copied 0 images to data/validation/091
# Copied 1 images to data/train/099
# Copied 1 images to data/validation/099
# Copied 8 images to data/train/096
# Copied 8 images to data/validation/096
# Copied 5 images to data/train/092
# Copied 8 images to data/validation/092
# Copied 1 images to data/train/095
# Copied 2 images to data/validation/095

# %%
/content/data
